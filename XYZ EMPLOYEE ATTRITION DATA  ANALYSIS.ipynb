# %%
print('IMPORTING LIBRARIES,LOAD THE DATA AND DATA DESCRIPTION ')
# Out:
# IMPORTING LIBRARIES,LOAD THE DATA AND DATA DESCRIPTION

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = "plotly_white"

data = pd.read_csv('attrition data.csv')
data.head()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel Rarely                   Sales
# 1           2   31       Yes  Travel Frequently  Research & Development
# 2           3   32        No  Travel Frequently  Research & Development
# 3           4   38        No         Non Travel  Research & Development
# 4           5   32        No      Travel Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
print('DATA EXPLORATION,Showing the data shape,Basic statistics of the data and information about the data types,it is done to check the missing values, data types and basic statistics')
# Out:
# DATA EXPLORATION,Showing the data shape,Basic statistics of the data and information about the data types,it is done to check the missing values, data types and basic statistics

# %%
# Check the shape of the dataset
print(data.shape)

# Get basic statistics
print(data.describe())

# Check for missing values
print(data.isnull().sum())

# Get information about data types
print(data.info())
# Out:
# (4410, 29)
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# count  4410.000000         4410.000000        4410.000000         4410.0
# mean      2.063946            2.683220          15.209524            8.0
# ...

# %%
print('DATA STATISTIC BY CHI-SQUARE STATISTIC')

# %%
from scipy import stats

# Chi-square test for categorical variables
contingency_table = pd.crosstab(data['Department'], data['Attrition'])
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print(f"Chi-square Statistic: {chi2}, P-value: {p}")
# Out:
# Chi-square Statistic: 29.090274924488263, P-value: 4.820888218170407e-07

# %%
print('DATA CLEANING.The data was cleaned and transformed using excel before proceding to analyse to removed unwanted coment that will not help to give accurate outcome of the data analization result')
# Out:
# DATA CLEANING.The data was cleaned and transformed using excel before proceding to analyse to removed unwanted coment that will not help to give accurate outcome of the data analization result

# %%
print('DATA VISUALIZATION')
print('The data is visualize to Identitfy the pattern and trend by the attrition by Department,Age Distribution.The data of the employee attrition is visualised to make inform decision, here is visualise to identify patterns and trends by plotting the distribution of employees who left(YES) vs those who stayed (NO)')
# Out:
# DATA VISUALIZATION
# The data is visualize to Identitfy the pattern and trend by the attrition by Department,Age Distribution.The data of the employee attrition is visualised to make inform decision, here is visualise to identify patterns and trends by plotting the distribution of employees who left(YES) vs those who stayed (NO)

# %%
# Attrition by Department
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', hue='Attrition', data=data)
plt.title('Attrition by Department')
plt.show()

#  Attrition by Age
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='Age', data=data)
plt.title('Age Distribution by Attrition')
plt.show()

# %%
print('I visualised the data using by using Histogram with the title Distribution by Age, the count represent the number of employees counted and the Age represent the age of the employee attrition by retirement due to aging conditions')
# Out:
# I visualised the data using by using Histogram with the title Distribution by Age, the count represent the number of employees counted and the Age represent the age of the employee attrition by retirement due to aging conditions

# %%
sns.displot(data['Age'], kde=True)
plt.title('Distribution of Age')
plt.show()

# %%
print('DATA VISUALIZATION.I analysed the data by visualizing  the data to show the relationship between the age and attrition,This is conducted to see the employees that will be leaving due to thier retirement age represented by yes and those staying represented by NO.Enhance this is done see certain factors significantly affecting the attrition rate')
# Out:
# DATA VISUALIZATION.I analysed the data by visualizing  the data to show the relationship between the age and attrition,This is conducted to see the employees that will be leaving due to thier retirement age represented by yes and those staying represented by NO.Enhance this is done see certain factors significantly affecting the attrition rate

# %%
# Analyze the relationship between age and attrition
plt.figure(figsize=(10, 6))
sns.boxplot(x='Attrition', y='Age', data=data, palette='Set2')
plt.title('Age Distribution by Attrition Status')
plt.xlabel('Attrition')
plt.ylabel('Age')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()

# %%
print('DATA VISUALIZATION BY CORRELATION. A heatmap shown help to visualise the correlation between the numerical features in the employees attrition, It is done to interprete the emplyees data base on demographic factors vs attrition,job satisfaction vs attrition,etc.The correlation matrix also helps to identify key variables,improves predictves accuracy,data driven decision making,reduce turnover cost, targeted interventions and enhance employee retension')
# Out:
# DATA VISUALIZATION BY CORRELATION. A heatmap shown help to visualise the correlation between the numerical features in the employees attrition, It is done to interprete the emplyees data base on demographic factors vs attrition,job satisfaction vs attrition,etc.The correlation matrix also helps to identify key variables,improves predictves accuracy,data driven decision making,reduce turnover cost, targeted interventions and enhance employee retension

# %%
# Correlation matrix
correlation = data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\MICHAEL JELEMON\AppData\Local\Temp\ipykernel_10980\349327378.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data.corr()

# %%
print('DATA VISUALIZATION BY PIE CHART. Pie chart is used to present the data to that count the occurances of each unique value in the attrition column, which provides the number of employees who left(YES) and the number of employees who stayed(NO).')
# Out:
# DATA VISUALIZATION BY PIE CHART. Pie chart is used to present the data to that count the occurances of each unique value in the attrition column, which provides the number of employees who left(YES) and the number of employees who stayed(NO).

# %%
# Step 1: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Load the Employee Attrition Dataset
# Replace 'employee_data.csv' with the path to your actual dataset
data = pd.read_csv('attrition data.csv')

# Step 3: Prepare the Data for the Pie Chart
# Count the number of employees who left vs those who stayed
attrition_counts = data['Attrition'].value_counts()

# Step 4: Create the Pie Chart
plt.figure(figsize=(8, 6))
plt.pie(
    attrition_counts,
    labels=attrition_counts.index,
    autopct='%1.1f%%',  # Display percentages
    startangle=140,      # Start angle for the pie chart
    colors=['#ff9999','#66b3ff']  # Optional: specify colors for the pie slices
)

# Adding title
plt.title('Employee Attrition Distribution')

# Display the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
